# %%
import numpy as np
import pandas as pd
import seaborn as sns
from sklearn.preprocessing import StandardScaler
df=pd.read_csv('/home/student/2025510071/heart.csv')
def standardize_data(X):
    mean = np.mean(X, axis=0)
    std = np.std(X, axis=0)
    return (X - mean) / std
def covariance_matrix(X):
    return np.cov(X, rowvar=False)
def compute_eigenvectors(cov_matrix):
    eigenvalues, eigenvectors = np.linalg.eig(cov_matrix)
    return eigenvalues, eigenvectors
def sort_eigenvectors(eigenvalues, eigenvectors):
    sorted_indices = np.argsort(eigenvalues)[::-1]
    sorted_eigenvalues = eigenvalues[sorted_indices]
    sorted_eigenvectors = eigenvectors[:, sorted_indices]
    return sorted_eigenvalues, sorted_eigenvectors
def project_data(X, eigenvectors, k):
    return X.dot(eigenvectors[:, :k])
def PCA(X, k):
    X_standardized = standardize_data(X)
    cov_matrix = covariance_matrix(X_standardized)
    eigenvalues, eigenvectors = compute_eigenvectors(cov_matrix)
    sorted_eigenvalues, sorted_eigenvectors = sort_eigenvectors(eigenvalues, eigenvectors)
    X_pca = project_data(X_standardized, sorted_eigenvectors, k)
    return X_pca, sorted_eigenvalues[:k], sorted_eigenvectors[:, :k]
if __name__=='__main__':
    X_pca, eigenvalues, eigenvectors = PCA(df, k=2)
    print("Projected Data:\n", X_pca)
    print("Eigenvalues:\n", eigenvalues)
    print("Eigenvectors:\n", eigenvectors)
# Out:
# Projected Data:
#                         0                   1
# 0     0.118775+0.000000j -1.431859+0.000000j
# 1     2.787517+0.000000j -0.316541+0.000000j
# 2     3.181313+0.000000j -0.933390+0.000000j
# 3     0.086071+0.000000j -0.588378+0.000000j
# 4     2.295406+0.000000j  2.075434+0.000000j
# ...                  ...                 ...
# 1020 -1.074554+0.000000j -0.477057+0.000000j
# 1021  2.646154+0.000000j -0.787495+0.000000j
# 1022  1.643544+0.000000j -1.406538+0.000000j
# 1023 -1.896457+0.000000j  0.067728+0.000000j
# 1024  1.374259+0.000000j -1.747623+0.000000j
#
# [1025 rows x 2 columns]
# Eigenvalues:
#  [3.31698522+0.j 1.58975444+0.j]
# Eigenvectors:
#  [[ 0.25204798+0.j  0.43470184+0.j]
#  [ 0.11262466+0.j -0.3975305 +0.j]
#  [-0.28192384+0.j  0.24459464+0.j]
#  [ 0.14307666+0.j  0.44536132+0.j]
#  [ 0.10219155+0.j  0.3683942 +0.j]
#  [ 0.06036591+0.j  0.31229842+0.j]
#  [-0.11269204+0.j -0.23758316+0.j]
#  [-0.36777036+0.j  0.01825414+0.j]
# ...

# %%
import numpy as np
import pandas as pd
import seaborn as sns
from sklearn.preprocessing import StandardScaler
df=pd.read_csv('/home/student/2025510071/diabetes.csv')
def standardize_data(X):
    mean = np.mean(X, axis=0)
    std = np.std(X, axis=0)
    return (X - mean) / std
def covariance_matrix(X):
    return np.cov(X, rowvar=False)
def compute_eigenvectors(cov_matrix):
    eigenvalues, eigenvectors = np.linalg.eig(cov_matrix)
    return eigenvalues, eigenvectors
def sort_eigenvectors(eigenvalues, eigenvectors):
    sorted_indices = np.argsort(eigenvalues)[::-1]
    sorted_eigenvalues = eigenvalues[sorted_indices]
    sorted_eigenvectors = eigenvectors[:, sorted_indices]
    return sorted_eigenvalues, sorted_eigenvectors
def project_data(X, eigenvectors, k):
    return X.dot(eigenvectors[:, :k])
def PCA(X, k):
    X_standardized = standardize_data(X)
    cov_matrix = covariance_matrix(X_standardized)
    eigenvalues, eigenvectors = compute_eigenvectors(cov_matrix)
    sorted_eigenvalues, sorted_eigenvectors = sort_eigenvectors(eigenvalues, eigenvectors)
    X_pca = project_data(X_standardized, sorted_eigenvectors, k)
    return X_pca, sorted_eigenvalues[:k], sorted_eigenvectors[:, :k]
if __name__=='__main__':
    X_pca, eigenvalues, eigenvectors = PCA(df, k=2)
    print("Projected Data:\n", X_pca)
    print("Eigenvalues:\n", eigenvalues)
    print("Eigenvectors:\n", eigenvectors)
# Out:
# Projected Data:
#                        0                   1
# 0   -2.012344+0.000000j -0.604476+0.000000j
# 1    1.758169+0.000000j  0.116622+0.000000j
# 2   -1.341963+0.000000j -0.430132+0.000000j
# 3    2.245240+0.000000j  0.341431+0.000000j
# 4   -1.487867+0.000000j  3.586527+0.000000j
# ..                  ...                 ...
# 763 -1.495686+0.000000j -2.228062+0.000000j
# 764  0.734019+0.000000j  0.573735+0.000000j
# 765  1.126252+0.000000j -0.815592+0.000000j
# 766 -0.545942+0.000000j  0.109957+0.000000j
# 767  1.498643+0.000000j  0.653115+0.000000j
#
# [768 rows x 2 columns]
# Eigenvalues:
#  [2.78511185+0.j 1.50766014+0.j]
# Eigenvectors:
#  [[-0.24319353+0.j -0.58236878+0.j]
#  [-0.42141852+0.j  0.06303707+0.j]
#  [-0.29086395+0.j -0.22910272+0.j]
#  [-0.35490014+0.j  0.24971756+0.j]
#  [-0.34825241+0.j  0.20951108+0.j]
#  [-0.35938891+0.j  0.33982951+0.j]
#  [-0.15622472+0.j  0.2585765 +0.j]
#  [-0.30688331+0.j -0.55791506+0.j]
#  [-0.4285834 +0.j  0.06720123+0.j]]

# %%
import numpy as np
import pandas as pd
import seaborn as sns
from sklearn.preprocessing import StandardScaler
df=pd.read_csv('/home/student/2025510071/winequality-red.csv')
def standardize_data(X):
    mean = np.mean(X, axis=0)
    std = np.std(X, axis=0)
    return (X - mean) / std
def covariance_matrix(X):
    return np.cov(X, rowvar=False)
def compute_eigenvectors(cov_matrix):
    eigenvalues, eigenvectors = np.linalg.eig(cov_matrix)
    return eigenvalues, eigenvectors
def sort_eigenvectors(eigenvalues, eigenvectors):
    sorted_indices = np.argsort(eigenvalues)[::-1]
    sorted_eigenvalues = eigenvalues[sorted_indices]
    sorted_eigenvectors = eigenvectors[:, sorted_indices]
    return sorted_eigenvalues, sorted_eigenvectors
def project_data(X, eigenvectors, k):
    return X.dot(eigenvectors[:, :k])
def PCA(X, k):
    X_standardized = standardize_data(X)
    cov_matrix = covariance_matrix(X_standardized)
    eigenvalues, eigenvectors = compute_eigenvectors(cov_matrix)
    sorted_eigenvalues, sorted_eigenvectors = sort_eigenvectors(eigenvalues, eigenvectors)
    X_pca = project_data(X_standardized, sorted_eigenvectors, k)
    return X_pca, sorted_eigenvalues[:k], sorted_eigenvectors[:, :k]
if __name__=='__main__':
    X_pca, eigenvalues, eigenvectors = PCA(df, k=2)
    print("Projected Data:\n", X_pca)
    print("Eigenvalues:\n", eigenvalues)
    print("Eigenvectors:\n", eigenvectors)
# Out:
# Projected Data:
#                         0                   1
# 0    -1.779442+0.000000j  1.157303+0.000000j
# 1    -1.004185+0.000000j  2.071838+0.000000j
# 2    -0.915783+0.000000j  1.393434+0.000000j
# 3     2.404077+0.000000j -0.213792+0.000000j
# 4    -1.779442+0.000000j  1.157303+0.000000j
# ...                  ...                 ...
# 1594 -2.241991+0.000000j  0.599594+0.000000j
# 1595 -2.122456+0.000000j -0.370101+0.000000j
# 1596 -1.366265+0.000000j -0.517561+0.000000j
# 1597 -2.367147+0.000000j  0.703545+0.000000j
# 1598 -0.288776+0.000000j -1.240846+0.000000j
#
# [1599 rows x 2 columns]
# Eigenvalues:
#  [3.12312087+0.j 2.24328497+0.j]
# Eigenvectors:
#  [[ 0.48788336+0.j -0.00417321+0.j]
#  [-0.26512898+0.j  0.33896786+0.j]
#  [ 0.47333547+0.j -0.1373581 +0.j]
#  [ 0.13915442+0.j  0.16773634+0.j]
#  [ 0.19742679+0.j  0.18978819+0.j]
#  [-0.04588071+0.j  0.25948314+0.j]
#  [ 0.00406675+0.j  0.36397137+0.j]
#  [ 0.37030119+0.j  0.33078079+0.j]
# ...
